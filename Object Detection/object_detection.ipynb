# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("input/wolf.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap="gray")
plt.show()

# %%
_, image_thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
plt.imshow(image_thresh, cmap="gray")
plt.axis('off')
plt.show()

# %%
contours, _= cv2.findContours(image_thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

result = image.copy()

for contour in contours:
    if cv2.contourArea(contour) > 1000:
        x, y, w, h = cv2.boundingRect(contour)
        print(contours)
        cv2.rectangle(result, (x, y), (x+w, y+h), (255, 255, 255), 3)

plt.imshow(result, cmap="gray")
plt.axis('off')
plt.show()
# Out:
# (array([[[586, 739]],
#
#        [[587, 739]]], dtype=int32), array([[[592, 733]],
#
#        [[591, 734]],
#
#        [[591, 735]],
#
#        [[590, 736]],
#
#        [[592, 734]],
#
#        [[593, 734]],
#
#        [[593, 733]]], dtype=int32), array([[[321, 732]],
#
#        [[321, 735]]], dtype=int32), array([[[693, 722]],
#
#        [[694, 722]]], dtype=int32), array([[[403, 720]],
#
#        [[404, 720]]], dtype=int32), array([[[466, 718]]], dtype=int32), array([[[433, 717]]], dtype=int32), array([[[683, 716]],
#
#        [[684, 716]]], dtype=int32), array([[[584, 715]]], dtype=int32), array([[[527, 713]],
#
#        [[529, 713]]], dtype=int32), array([[[380, 712]],
#
#        [[381, 712]],
#
#        [[382, 713]],
#
#        [[386, 713]],
#
#        [[384, 713]],
#
#        [[383, 712]]], dtype=int32), array([[[647, 711]]], dtype=int32), array([[[432, 710]],
#
#        [[432, 711]]], dtype=int32), array([[[430, 709]]], dtype=int32), array([[[510, 707]]], dtype=int32), array([[[470, 706]]], dtype=int32), array([[[475, 703]],
#
#        [[475, 704]]], dtype=int32), array([[[498, 702]],
#
#        [[499, 703]],
#
#        [[500, 703]],
#
#        [[502, 705]],
#
#        [[505, 705]],
#
#        [[503, 705]],
#
#        [[502, 704]],
#
#        [[501, 704]],
#
#        [[500, 703]],
#
#        [[499, 703]]], dtype=int32), array([[[326, 698]],
#
#        [[325, 699]],
#
#        [[326, 700]]], dtype=int32), array([[[385, 695]]], dtype=int32), array([[[356, 693]]], dtype=int32), array([[[386, 691]]], dtype=int32), array([[[368, 689]],
#
#        [[369, 689]]], dtype=int32), array([[[536, 688]],
#
#        [[536, 689]]], dtype=int32), array([[[290, 686]],
#
#        [[290, 687]]], dtype=int32), array([[[712, 684]]], dtype=int32), array([[[480, 683]]], dtype=int32), array([[[720, 682]],
#
#        [[720, 687]],
#
#        [[721, 688]],
#
#        [[721, 685]],
#
#        [[720, 684]]], dtype=int32), array([[[651, 682]]], dtype=int32), array([[[648, 682]]], dtype=int32), array([[[270, 682]],
#
#        [[270, 683]]], dtype=int32), array([[[848, 681]],
#
#        [[848, 682]]], dtype=int32), array([[[474, 680]],
#
#        [[473, 681]],
#
#        [[471, 681]],
#
#        [[478, 681]],
#
#        [[479, 680]],
#
#        [[481, 680]]], dtype=int32), array([[[484, 679]],
#
#        [[483, 680]],
#
#        [[484, 680]],
#
#        [[485, 679]],
#
#        [[486, 679]]], dtype=int32), array([[[654, 678]],
#
#        [[655, 678]]], dtype=int32), array([[[747, 677]]], dtype=int32), array([[[712, 677]],
#
#        [[712, 678]]], dtype=int32), array([[[509, 677]],
#
#        [[511, 677]]], dtype=int32), array([[[496, 676]],
#
#        [[498, 676]]], dtype=int32), array([[[382, 676]],
#
#        [[383, 677]],
#
#        [[384, 677]],
#
#        [[383, 676]]], dtype=int32), array([[[236, 676]]], dtype=int32), array([[[267, 675]],
#
#        [[267, 676]],
#
#        [[266, 677]],
#
#        [[267, 678]],
#
#        [[268, 678]],
#
#        [[268, 677]],
#
#        [[267, 676]]], dtype=int32), array([[[505, 674]],
#
#        [[506, 675]]], dtype=int32), array([[[323, 674]],
#
#        [[325, 674]]], dtype=int32), array([[[259, 674]]], dtype=int32), array([[[253, 674]],
#
#        [[253, 675]],
#
#        [[256, 675]],
#
#        [[255, 675]],
#
#        [[254, 674]]], dtype=int32), array([[[240, 674]],
#
#        [[245, 674]],
#
#        [[246, 675]],
#
#        [[250, 675]],
#
#        [[248, 675]],
#
#        [[247, 674]]], dtype=int32), array([[[855, 673]]], dtype=int32), array([[[759, 672]],
#
#        [[759, 674]],
#
#        [[759, 673]],
#
#        [[760, 672]]], dtype=int32), array([[[251, 672]]], dtype=int32), array([[[494, 671]],
#
#        [[493, 672]],
#
#        [[492, 672]],
#
#        [[493, 672]],
#
#        [[494, 671]],
#
#        [[496, 671]]], dtype=int32), array([[[374, 671]],
#
#        [[374, 672]]], dtype=int32), array([[[426, 670]]], dtype=int32), array([[[265, 670]],
#
#        [[263, 672]],
#
#        [[263, 673]],
#
#        [[265, 671]]], dtype=int32), array([[[698, 669]]], dtype=int32), array([[[370, 669]]], dtype=int32), array([[[232, 669]],
#
#        [[233, 670]],
#
#        [[233, 671]],
#
#        [[235, 673]],
#
#        [[233, 671]],
#
#        [[233, 670]]], dtype=int32), array([[[427, 668]]], dtype=int32), array([[[340, 668]]], dtype=int32), array([[[761, 667]],
#
#        [[761, 668]],
#
#        [[762, 668]],
#
#        [[762, 667]]], dtype=int32), array([[[736, 667]],
#
#        [[735, 668]],
#
#        [[733, 668]],
#
#        [[733, 670]],
#
#        [[732, 671]],
#
#        [[731, 671]],
#
#        [[730, 672]],
#
#        [[731, 673]],
#
#        [[732, 673]],
#
#        [[732, 672]],
#
#        [[733, 671]],
#
#        [[734, 671]],
#
#        [[735, 672]],
#
#        [[735, 670]],
#
#        [[736, 669]],
#
#        [[738, 669]],
#
#        [[739, 670]],
#
#        [[737, 672]],
#
#        [[738, 671]],
#
#        [[739, 671]],
#
#        [[739, 668]],
#
#        [[737, 668]]], dtype=int32), array([[[361, 667]],
#
#        [[362, 668]]], dtype=int32), array([[[343, 666]],
#
#        [[344, 667]]], dtype=int32), array([[[248, 666]]], dtype=int32), array([[[750, 665]],
#
#        [[750, 666]],
#
#        [[754, 666]],
#
#        [[754, 665]]], dtype=int32), array([[[763, 664]]], dtype=int32), array([[[681, 664]],
#
#        [[683, 664]],
#
#        [[684, 665]],
#
#        [[685, 665]],
#
#        [[686, 666]],
#
#        [[687, 666]],
#
#        [[689, 668]],
#
#        [[690, 668]],
#
#        [[691, 669]],
#
#        [[692, 669]],
#
#        [[690, 667]],
#
#        [[688, 667]],
#
#        [[686, 665]],
#
#        [[684, 665]],
#
#        [[683, 664]]], dtype=int32), array([[[328, 664]],
#
#        [[329, 665]]], dtype=int32), array([[[258, 664]],
#
#        [[258, 666]],
#
#        [[259, 665]],
#
#        [[259, 664]]], dtype=int32), array([[[268, 663]],
#
#        [[269, 664]],
#
#        [[269, 666]],
#
#        [[270, 667]],
#
#        [[270, 668]],
#
#        [[271, 669]],
#
#        [[270, 668]],
#
#        [[270, 667]],
#
#        [[269, 666]],
#
#        [[269, 664]]], dtype=int32), array([[[370, 662]],
#
#        [[370, 663]],
#
#        [[372, 665]],
#
#        [[372, 667]],
#
#        [[373, 668]],
#
#        [[373, 669]],
#
#        [[373, 668]],
#
#        [[372, 667]],
#
#        [[372, 665]],
#
#        [[371, 664]],
#
#        [[371, 663]]], dtype=int32), array([[[226, 662]]], dtype=int32), array([[[710, 661]],
#
#        [[710, 662]],
#
#        [[711, 662]],
#
#        [[711, 661]]], dtype=int32), array([[[573, 661]],
#
#        [[573, 662]],
#
#        [[577, 662]],
#
#        [[577, 661]]], dtype=int32), array([[[565, 661]],
#
#        [[569, 661]]], dtype=int32), array([[[447, 661]],
#
#        [[448, 661]]], dtype=int32), array([[[315, 661]]], dtype=int32), array([[[267, 661]]], dtype=int32), array([[[202, 660]],
#
#        [[204, 660]],
#
#        [[205, 661]],
#
#        [[207, 661]],
#
#        [[205, 661]],
#
#        [[204, 660]]], dtype=int32), array([[[351, 659]],
#
#        [[352, 659]]], dtype=int32), array([[[311, 659]]], dtype=int32), array([[[266, 659]]], dtype=int32), array([[[453, 658]],
#
#        [[455, 658]]], dtype=int32), array([[[404, 658]]], dtype=int32), array([[[398, 658]]], dtype=int32), array([[[306, 658]],
#
#        [[306, 659]]], dtype=int32), array([[[216, 658]]], dtype=int32), array([[[395, 657]],
#
#        [[396, 657]]], dtype=int32), array([[[116, 657]],
#
#        [[116, 658]]], dtype=int32), array([[[640, 656]]], dtype=int32), array([[[429, 656]]], dtype=int32), array([[[215, 656]],
#
#        [[216, 656]]], dtype=int32), array([[[367, 655]]], dtype=int32), array([[[264, 655]]], dtype=int32), array([[[175, 654]],
#
#        [[176, 655]],
#
#        [[177, 655]],
#
#        [[176, 654]]], dtype=int32), array([[[437, 653]]], dtype=int32), array([[[349, 652]]], dtype=int32), array([[[293, 652]],
#
#        [[295, 652]]], dtype=int32), array([[[215, 652]]], dtype=int32), array([[[227, 651]]], dtype=int32), array([[[198, 651]]], dtype=int32), array([[[179, 651]]], dtype=int32), array([[[298, 650]]], dtype=int32), array([[[268, 650]]], dtype=int32), array([[[428, 649]],
#
#        [[428, 654]]], dtype=int32), array([[[591, 648]]], dtype=int32), array([[[276, 648]],
#
#        [[276, 649]],
#
#        [[277, 649]],
#
#        [[277, 648]]], dtype=int32), array([[[165, 648]],
#
#        [[166, 649]]], dtype=int32), array([[[322, 647]]], dtype=int32), array([[[265, 647]],
#
#        [[266, 648]],
#
#        [[266, 647]]], dtype=int32), array([[[236, 647]],
#
#        [[237, 648]],
#
#        [[237, 649]],
#
#        [[238, 650]],
#
#        [[238, 652]],
#
#        [[239, 652]],
#
#        [[239, 651]],
#
#        [[237, 649]],
#
#        [[237, 648]]], dtype=int32), array([[[229, 647]],
#
#        [[228, 648]],
#
#        [[229, 648]]], dtype=int32), array([[[262, 646]],
#
#        [[263, 646]]], dtype=int32), array([[[177, 646]]], dtype=int32), array([[[574, 645]],
#
#        [[576, 645]],
#
#        [[577, 646]],
#
#        [[578, 646]],
#
#        [[579, 647]],
#
#        [[579, 646]],
#
#        [[578, 645]]], dtype=int32), array([[[568, 645]],
#
#        [[568, 649]],
#
#        [[567, 650]],
#
#        [[566, 649]],
#
#        [[566, 648]],
#
#        [[565, 648]],
#
#        [[566, 649]],
#
#        [[566, 652]],
#
#        [[568, 650]],
#
#        [[569, 651]],
#
#        [[569, 652]],
#
#        [[568, 653]],
#
#        [[568, 654]],
#
#        [[569, 653]],
#
#        [[575, 653]],
#
#        [[575, 652]],
#
#        [[574, 651]],
#
#        [[575, 650]],
#
#        [[574, 650]],
#
#        [[573, 649]],
#
#        [[572, 649]],
#
#        [[571, 648]],
#
#        [[571, 647]],
#
#        [[569, 645]]], dtype=int32), array([[[572, 652]],
#
#        [[573, 651]],
#
#        [[574, 652]],
#
#        [[573, 653]]], dtype=int32), array([[[566, 645]]], dtype=int32), array([[[234, 644]]], dtype=int32), array([[[231, 644]]], dtype=int32), array([[[192, 644]],
#
#        [[193, 645]],
#
#        [[195, 645]],
#
#        [[194, 644]]], dtype=int32), array([[[179, 644]]], dtype=int32), array([[[773, 643]]], dtype=int32), array([[[255, 643]],
#
#        [[259, 647]],
#
#        [[260, 646]],
#
#        [[258, 646]]], dtype=int32), array([[[249, 643]],
#
#        [[247, 645]],
#
#        [[247, 646]],
#
#        [[246, 647]],
#
#        [[247, 646]],
#
#        [[247, 645]]], dtype=int32), array([[[204, 643]],
#
#        [[203, 644]],
#
#        [[203, 647]],
#
#        [[203, 644]]], dtype=int32), array([[[737, 642]],
#
#        [[737, 643]]], dtype=int32), array([[[191, 642]]], dtype=int32), array([[[148, 642]]], dtype=int32), array([[[181, 641]]], dtype=int32), array([[[158, 641]]], dtype=int32), array([[[668, 640]],
#
#        [[669, 640]]], dtype=int32), array([[[678, 639]]], dtype=int32), array([[[325, 639]],
#
#        [[326, 640]]], dtype=int32), array([[[292, 639]],
#
#        [[291, 640]],
#
#        [[290, 640]],
#
#        [[293, 640]],
#
#        [[293, 639]]], dtype=int32), array([[[203, 639]],
#
#        [[202, 640]]], dtype=int32), array([[[252, 638]],
#
#        [[251, 639]]], dtype=int32), array([[[248, 638]]], dtype=int32), array([[[347, 637]],
#
#        [[347, 638]]], dtype=int32), array([[[279, 637]]], dtype=int32), array([[[322, 636]],
#
#        [[321, 637]]], dtype=int32), array([[[266, 636]],
#
#        [[266, 637]],
#
#        [[267, 638]],
#
#        [[267, 639]],
#
#        [[268, 640]],
#
#        [[268, 639]],
#
#        [[267, 638]],
#
#        [[267, 637]]], dtype=int32), array([[[245, 636]]], dtype=int32), array([[[235, 636]]], dtype=int32), array([[[204, 636]],
#
#        [[204, 637]]], dtype=int32), array([[[629, 635]],
#
#        [[630, 636]],
#
#        [[630, 635]]], dtype=int32), array([[[621, 635]],
#
#        [[626, 635]]], dtype=int32), array([[[324, 635]]], dtype=int32), array([[[254, 635]],
#
#        [[253, 636]]], dtype=int32), array([[[694, 634]],
#
#        [[694, 635]],
#
#        [[693, 636]],
#
#        [[693, 637]],
#
#        [[693, 636]],
#
#        [[694, 635]]], dtype=int32), array([[[635, 634]]], dtype=int32), array([[[259, 634]]], dtype=int32), array([[[695, 632]]], dtype=int32), array([[[689, 632]]], dtype=int32), array([[[250, 632]]], dtype=int32), array([[[213, 632]]], dtype=int32), array([[[187, 632]],
#
#        [[188, 633]],
#
#        [[191, 633]],
#
#        [[189, 633]],
#
#        [[188, 632]]], dtype=int32), array([[[183, 632]],
#
#        [[184, 632]]], dtype=int32), array([[[675, 631]],
#
#        [[676, 632]],
#
#        [[677, 632]],
#
#        [[676, 632]]], dtype=int32), array([[[624, 631]],
#
#        [[624, 632]],
#
#        [[625, 632]],
#
#        [[625, 631]]], dtype=int32), array([[[193, 631]],
#
#        [[194, 632]],
#
#        [[194, 633]],
#
#        [[194, 632]]], dtype=int32), array([[[ 72, 631]],
#
#        [[ 73, 632]],
#
#        [[ 74, 632]],
#
#        [[ 73, 631]]], dtype=int32), array([[[693, 630]],
#
#        [[692, 631]],
#
#        [[691, 631]],
#
#        [[692, 631]]], dtype=int32), array([[[714, 629]],
#
#        [[714, 630]],
#
#        [[712, 632]],
#
#        [[714, 630]]], dtype=int32), array([[[234, 629]],
#
#        [[234, 631]],
#
#        [[235, 632]],
#
#        [[235, 631]],
#
#        [[234, 630]]], dtype=int32), array([[[722, 628]],
#
#        [[719, 631]],
#
#        [[719, 632]],
#
#        [[718, 633]],
#
#        [[721, 630]],
#
#        [[721, 629]]], dtype=int32), array([[[701, 628]],
#
#        [[700, 629]],
#
#        [[699, 629]],
#
#        [[697, 631]],
#
#        [[698, 630]],
#
#        [[699, 630]]], dtype=int32), array([[[670, 628]]], dtype=int32), array([[[653, 628]],
#
#        [[653, 630]],
#
#        [[654, 630]],
#
#        [[653, 629]]], dtype=int32), array([[[412, 628]],
#
#        [[408, 632]],
#
#        [[409, 632]],
#
#        [[409, 631]],
#
#        [[410, 630]],
#
#        [[411, 630]],
#
#        [[413, 628]]], dtype=int32), array([[[274, 628]],
#
#        [[275, 629]],
#
#        [[276, 629]],
#
#        [[275, 628]]], dtype=int32), array([[[268, 628]]], dtype=int32), array([[[690, 627]]], dtype=int32), array([[[391, 627]],
#
#        [[393, 627]]], dtype=int32), array([[[704, 626]]], dtype=int32), array([[[754, 625]]], dtype=int32), array([[[655, 625]],
#
#        [[656, 625]],
#
#        [[657, 626]],
#
#        [[659, 626]],
#
#        [[660, 627]],
#
#        [[660, 626]],
#
#        [[659, 626]],
#
#        [[658, 625]]], dtype=int32), array([[[783, 624]],
#
#        [[783, 625]],
#
#        [[784, 625]]], dtype=int32), array([[[733, 624]],
#
#        [[733, 627]],
#
#        [[731, 629]],
#
#        [[731, 630]],
#
#        [[732, 629]],
#
#        [[732, 628]],
#
#        [[733, 627]]], dtype=int32), array([[[272, 624]],
#
#        [[270, 626]],
#
#        [[271, 626]],
#
#        [[271, 625]]], dtype=int32), array([[[205, 624]]], dtype=int32), array([[[728, 623]]], dtype=int32), array([[[423, 623]]], dtype=int32), array([[[809, 622]],
#
#        [[809, 623]]], dtype=int32), array([[[649, 622]],
#
#        [[649, 624]],
#
#        [[652, 624]],
#
#        [[651, 624]],
#
#        [[650, 623]],
#
#        [[650, 622]]], dtype=int32), array([[[221, 622]],
#
#        [[223, 622]]], dtype=int32), array([[[163, 622]]], dtype=int32), array([[[769, 621]],
#
#        [[771, 621]],
#
#        [[772, 622]],
#
#        [[774, 622]],
#
#        [[775, 623]],
#
#        [[778, 623]],
#
#        [[776, 623]],
#
#        [[775, 622]],
#
#        [[772, 622]],
#
#        [[771, 621]]], dtype=int32), array([[[242, 621]],
#
#        [[242, 622]],
#
#        [[243, 622]]], dtype=int32), array([[[230, 621]],
#
#        [[231, 621]]], dtype=int32), array([[[765, 620]],
#
#        [[766, 620]]], dtype=int32), array([[[700, 620]]], dtype=int32), array([[[186, 620]],
#
#        [[186, 621]],
#
#        [[187, 621]]], dtype=int32), array([[[872, 619]],
#
#        [[872, 620]]], dtype=int32), array([[[712, 619]]], dtype=int32), array([[[667, 619]],
#
#        [[668, 619]]], dtype=int32), array([[[300, 619]],
#
#        [[299, 620]],
#
#        [[298, 620]],
#
#        [[299, 620]]], dtype=int32), array([[[235, 619]],
#
#        [[236, 619]]], dtype=int32), array([[[648, 618]],
#
#        [[648, 619]],
#
#        [[649, 619]]], dtype=int32), array([[[410, 618]],
#
#        [[410, 619]]], dtype=int32), array([[[297, 618]]], dtype=int32), array([[[242, 618]]], dtype=int32), array([[[238, 618]],
#
#        [[239, 618]]], dtype=int32), array([[[207, 618]],
#
#        [[206, 619]]], dtype=int32), array([[[729, 617]]], dtype=int32), array([[[404, 617]],
#
#        [[405, 618]],
#
#        [[405, 619]],
#
#        [[408, 622]],
#
#        [[406, 620]],
#
#        [[407, 619]],
#
#        [[406, 618]],
#
#        [[405, 618]]], dtype=int32), array([[[405, 619]],
#
#        [[406, 618]],
#
#        [[407, 619]],
#
#        [[406, 620]]], dtype=int32), array([[[720, 616]]], dtype=int32), array([[[396, 616]],
#
#        [[397, 616]]], dtype=int32), array([[[409, 615]]], dtype=int32), array([[[331, 615]]], dtype=int32), array([[[287, 615]]], dtype=int32), array([[[250, 615]]], dtype=int32), array([[[209, 615]]], dtype=int32), array([[[744, 614]]], dtype=int32), array([[[586, 614]],
#
#        [[585, 615]]], dtype=int32), array([[[393, 614]],
#
#        [[394, 615]]], dtype=int32), array([[[221, 614]],
#
#        [[222, 614]]], dtype=int32), array([[[649, 613]]], dtype=int32), array([[[397, 613]],
#
#        [[398, 614]]], dtype=int32), array([[[678, 612]]], dtype=int32), array([[[636, 612]],
#
#        [[637, 612]]], dtype=int32), array([[[404, 612]]], dtype=int32), array([[[353, 612]]], dtype=int32), array([[[266, 612]],
#
#        [[269, 615]],
#
#        [[270, 615]],
#
#        [[271, 616]],
#
#        [[271, 618]],
#
#        [[272, 619]],
#
#        [[272, 617]],
#
#        [[271, 616]],
#
#        [[271, 615]],
#
#        [[270, 615]],
#
#        [[269, 614]],
#
#        [[268, 614]]], dtype=int32), array([[[793, 611]],
#
#        [[793, 612]],
#
#        [[792, 613]],
#
#        [[793, 613]],
#
#        [[793, 612]],
#
#        [[794, 611]]], dtype=int32), array([[[336, 611]]], dtype=int32), array([[[333, 611]],
#
#        [[331, 613]],
#
#        [[329, 613]],
#
#        [[332, 613]],
#
#        [[333, 612]]], dtype=int32), array([[[317, 611]]], dtype=int32), array([[[293, 611]],
#
#        [[294, 611]]], dtype=int32), array([[[291, 611]]], dtype=int32), array([[[754, 610]],
#
#        [[754, 611]]], dtype=int32), array([[[264, 610]]], dtype=int32), array([[[250, 610]]], dtype=int32), array([[[764, 609]],
#
#        [[762, 611]],
#
#        [[762, 612]],
#
#        [[764, 610]]], dtype=int32), array([[[679, 609]],
#
#        [[680, 610]],
#
#        [[681, 609]],
#
#        [[682, 609]]], dtype=int32), array([[[227, 609]],
#
#        [[225, 611]],
#
#        [[224, 611]],
#
#        [[223, 610]],
#
#        [[222, 610]],
#
#        [[223, 611]],
#
#        [[223, 612]],
#
#        [[224, 612]],
#
#        [[227, 609]],
#
#        [[228, 609]]], dtype=int32), array([[[185, 609]],
#
#        [[185, 610]],
#
#        [[186, 609]]], dtype=int32), array([[[156, 609]],
#
#        [[157, 610]]], dtype=int32), array([[[390, 608]]], dtype=int32), array([[[356, 608]],
#
#        [[356, 609]],
#
#        [[355, 610]],
#
#        [[354, 610]],
#
#        [[355, 610]],
#
#        [[356, 609]],
#
#        [[358, 609]],
#
#        [[359, 610]],
#
#        [[360, 610]],
#
#        [[359, 610]],
#
#        [[358, 609]],
#
#        [[358, 608]]], dtype=int32), array([[[328, 608]],
#
#        [[329, 609]]], dtype=int32), array([[[263, 608]]], dtype=int32), array([[[173, 608]],
#
#        [[174, 609]],
#
#        [[175, 609]],
#
#        [[176, 608]]], dtype=int32), array([[[757, 607]]], dtype=int32), array([[[392, 607]],
#
#        [[393, 608]],
#
#        [[393, 609]],
#
#        [[394, 610]],
#
#        [[394, 609]],
#
#        [[393, 608]],
#
#        [[393, 607]]], dtype=int32), array([[[350, 607]],
#
#        [[351, 608]],
#
#        [[352, 608]],
#
#        [[351, 608]]], dtype=int32), array([[[344, 607]],
#
#        [[345, 607]]], dtype=int32), array([[[250, 607]],
#
#        [[251, 607]]], dtype=int32), array([[[155, 607]]], dtype=int32), array([[[815, 606]]], dtype=int32), array([[[768, 606]]], dtype=int32), array([[[275, 606]],
#
#        [[274, 607]],
#
#        [[272, 607]],
#
#        [[274, 607]],
#
#        [[275, 606]],
#
#        [[276, 606]]], dtype=int32), array([[[248, 606]]], dtype=int32), array([[[371, 605]],
#
#        [[371, 606]],
#
#        [[372, 606]],
#
#        [[373, 607]],
#
#        [[373, 606]],
#
#        [[372, 605]]], dtype=int32), array([[[361, 605]],
#
#        [[361, 607]],
#
#        [[362, 608]],
#
#        [[362, 607]],
#
#        [[361, 606]],
#
#        [[362, 605]]], dtype=int32), array([[[358, 605]],
#
#        [[358, 606]],
#
#        [[359, 606]],
#
#        [[359, 605]]], dtype=int32), array([[[273, 605]]], dtype=int32), array([[[270, 605]]], dtype=int32), array([[[170, 605]]], dtype=int32), array([[[404, 604]],
#
#        [[405, 605]]], dtype=int32), array([[[377, 604]],
#
#        [[377, 605]]], dtype=int32), array([[[266, 604]],
#
#        [[267, 604]]], dtype=int32), array([[[633, 603]]], dtype=int32), array([[[234, 603]],
#
#        [[231, 606]],
#
#        [[229, 606]],
#
#        [[230, 606]],
#
#        [[231, 607]],
#
#        [[233, 607]],
#
#        [[232, 606]],
#
#        [[232, 605]]], dtype=int32), array([[[222, 603]],
#
#        [[223, 603]],
#
#        [[224, 604]],
#
#        [[225, 604]],
#
#        [[224, 604]],
#
#        [[223, 603]]], dtype=int32), array([[[169, 603]]], dtype=int32), array([[[773, 602]],
#
#        [[773, 604]],
#
#        [[774, 604]],
#
#        [[773, 603]]], dtype=int32), array([[[756, 602]],
#
#        [[756, 603]],
#
#        [[755, 604]],
#
#        [[756, 603]]], dtype=int32), array([[[654, 602]],
#
#        [[654, 605]]], dtype=int32), array([[[362, 602]],
#
#        [[363, 602]],
#
#        [[365, 604]],
#
#        [[364, 605]],
#
#        [[364, 606]],
#
#        [[365, 606]],
#
#        [[365, 605]],
#
#        [[366, 604]],
#
#        [[367, 605]],
#
#        [[368, 605]],
#
#        [[370, 603]],
#
#        [[371, 603]],
#
#        [[370, 603]],
#
#        [[369, 604]],
#
#        [[368, 603]],
#
#        [[364, 603]],
#
#        [[363, 602]]], dtype=int32), array([[[341, 602]],
#
#        [[341, 603]]], dtype=int32), array([[[336, 602]]], dtype=int32), array([[[207, 602]],
#
#        [[206, 603]],
#
#        [[206, 604]],
#
#        [[207, 603]]], dtype=int32), array([[[198, 602]],
#
#        [[198, 603]],
#
#        [[200, 605]],
#
#        [[199, 604]],
#
#        [[199, 603]]], dtype=int32), array([[[195, 602]]], dtype=int32), array([[[397, 601]]], dtype=int32), array([[[374, 601]],
#
#        [[374, 603]]], dtype=int32), array([[[298, 601]],
#
#        [[299, 602]]], dtype=int32), array([[[236, 601]],
#
#        [[237, 602]],
#
#        [[237, 603]],
#
#        [[238, 602]],
#
#        [[237, 601]]], dtype=int32), array([[[214, 601]],
#
#        [[216, 601]]], dtype=int32), array([[[186, 601]],
#
#        [[186, 606]]], dtype=int32), array([[[135, 601]],
#
#        [[134, 602]],
#
#        [[126, 602]],
#
#        [[125, 603]],
#
#        [[129, 603]],
#
#        [[130, 602]],
#
#        [[135, 602]],
#
#        [[136, 601]]], dtype=int32), array([[[277, 600]]], dtype=int32), array([[[212, 600]],
#
#        [[211, 601]],
#
#        [[210, 601]],
#
#        [[211, 601]]], dtype=int32), array([[[361, 599]]], dtype=int32), array([[[349, 599]]], dtype=int32), array([[[166, 599]]], dtype=int32), array([[[766, 598]],
#
#        [[766, 603]],
#
#        [[765, 604]],
#
#        [[766, 604]],
#
#        [[766, 601]],
#
#        [[767, 600]],
#
#        [[767, 598]]], dtype=int32), array([[[758, 598]],
#
#        [[758, 599]]], dtype=int32), array([[[356, 598]],
#
#        [[357, 599]],
#
#        [[357, 600]],
#
#        [[359, 602]],
#
#        [[360, 602]],
#
#        [[360, 601]],
#
#        [[359, 601]]], dtype=int32), array([[[341, 598]]], dtype=int32), array([[[275, 598]]], dtype=int32), array([[[264, 598]]], dtype=int32), array([[[253, 598]],
#
#        [[254, 598]]], dtype=int32), array([[[249, 598]]], dtype=int32), array([[[242, 598]]], dtype=int32), array([[[236, 598]],
#
#        [[237, 599]],
#
#        [[239, 599]],
#
#        [[237, 599]]], dtype=int32), array([[[199, 598]],
#
#        [[200, 598]]], dtype=int32), array([[[832, 597]],
#
#        [[833, 598]],
#
#        [[833, 599]],
#
#        [[835, 601]],
#
#        [[835, 600]],
#
#        [[834, 600]],
#
#        [[833, 599]],
#
#        [[833, 598]]], dtype=int32), array([[[690, 597]],
#
#        [[690, 598]],
#
#        [[689, 599]],
#
#        [[688, 599]],
#
#        [[688, 600]],
#
#        [[691, 597]]], dtype=int32), array([[[343, 597]]], dtype=int32), array([[[247, 597]]], dtype=int32), array([[[244, 597]]], dtype=int32), array([[[229, 597]],
#
#        [[231, 597]]], dtype=int32), array([[[214, 597]]], dtype=int32), array([[[787, 596]]], dtype=int32), array([[[355, 596]]], dtype=int32), array([[[193, 596]]], dtype=int32), array([[[851, 595]]], dtype=int32), array([[[687, 595]],
#
#        [[686, 596]],
#
#        [[686, 601]],
#
#        [[686, 598]],
#
#        [[687, 597]]], dtype=int32), array([[[388, 595]],
#
#        [[388, 596]],
#
#        [[389, 597]],
#
#        [[389, 598]],
#
#        [[390, 597]],
#
#        [[391, 598]]], dtype=int32), array([[[348, 595]],
#
#        [[349, 595]]], dtype=int32), array([[[307, 595]]], dtype=int32), array([[[181, 595]],
#
#        [[182, 595]]], dtype=int32), array([[[295, 594]]], dtype=int32), array([[[247, 594]],
#
#        [[248, 594]],
#
#        [[249, 595]],
#
#        [[248, 594]]], dtype=int32), array([[[220, 594]],
#
#        [[221, 594]],
#
#        [[222, 595]],
#
#        [[224, 595]],
#
#        [[225, 596]],
#
#        [[225, 597]],
#
#        [[224, 598]],
#
#        [[223, 598]],
#
#        [[219, 602]],
#
#        [[218, 602]],
#
#        [[220, 602]],
#
#        [[221, 601]],
#
#        [[223, 601]],
#
#        [[222, 600]],
#
#        [[226, 596]],
#
#        [[225, 596]],
#
#        [[224, 595]],
#
#        [[223, 595]],
#
#        [[222, 594]]], dtype=int32), array([[[766, 593]],
#
#        [[766, 595]],
#
#        [[767, 595]],
#
#        [[766, 594]]], dtype=int32), array([[[682, 593]],
#
#        [[682, 594]],
#
#        [[683, 594]]], dtype=int32), array([[[319, 593]]], dtype=int32), array([[[253, 593]],
#
#        [[252, 594]],
#
#        [[253, 595]]], dtype=int32), array([[[217, 593]]], dtype=int32), array([[[761, 592]]], dtype=int32), array([[[641, 592]],
#
#        [[642, 592]]], dtype=int32), array([[[636, 592]],
#
#        [[635, 593]],
#
#        [[634, 593]],
#
#        [[635, 593]],
#
#        [[636, 592]],
#
#        [[637, 592]]], dtype=int32), array([[[400, 592]],
#
#        [[401, 593]],
#
#        [[401, 594]],
#
#        [[401, 593]]], dtype=int32), array([[[267, 592]]], dtype=int32), array([[[225, 592]],
#
#        [[225, 593]],
#
#        [[226, 593]]], dtype=int32), array([[[193, 591]]], dtype=int32), array([[[187, 591]],
#
#        [[189, 593]],
#
#        [[189, 594]],
#
#        [[191, 594]],
#
#        [[190, 593]],
#
#        [[189, 593]]], dtype=int32), array([[[174, 591]],
#
#        [[175, 591]]], dtype=int32), array([[[784, 590]]], dtype=int32), array([[[762, 590]]], dtype=int32), array([[[692, 590]]], dtype=int32), array([[[636, 590]],
#
#        [[637, 590]]], dtype=int32), array([[[358, 590]],
#
#        [[358, 595]]], dtype=int32), array([[[345, 590]],
#
#        [[344, 591]],
#
#        [[340, 591]],
#
#        [[341, 591]],
#
#        [[342, 592]],
#
#        [[343, 591]],
#
#        [[345, 591]],
#
#        [[346, 590]]], dtype=int32), array([[[199, 590]],
#
#        [[201, 590]]], dtype=int32), array([[[166, 590]]], dtype=int32), array([[[163, 590]],
#
#        [[164, 590]]], dtype=int32), array([[[111, 590]],
#
#        [[111, 591]]], dtype=int32), array([[[832, 589]],
#
#        [[833, 589]]], dtype=int32), array([[[731, 589]],
#
#        [[731, 590]],
#
#        [[730, 591]],
#
#        [[730, 593]],
#
#        [[729, 594]],
#
#        [[728, 594]],
#
#        [[728, 595]],
#
#        [[729, 596]],
#
#        [[729, 598]],
#
#        [[728, 599]],
#
#        [[728, 601]],
#
#        [[727, 602]],
#
#        [[728, 601]],
#
#        [[728, 599]],
#
#        [[729, 598]],
#
#        [[729, 595]],
#
#        [[730, 594]],
#
#        [[730, 592]],
#
#        [[731, 591]]], dtype=int32), array([[[639, 589]]], dtype=int32), array([[[779, 588]]], dtype=int32), array([[[763, 588]]], dtype=int32), array([[[690, 588]],
#
#        [[689, 589]],
#
#        [[689, 590]],
#
#        [[687, 592]],
#
#        [[690, 589]]], dtype=int32), array([[[674, 588]]], dtype=int32), array([[[769, 587]],
#
#        [[769, 588]],
#
#        [[770, 587]]], dtype=int32), array([[[766, 587]],
#
#        [[766, 590]],
#
#        [[766, 589]],
#
#        [[767, 588]]], dtype=int32), array([[[202, 587]],
#
#        [[203, 588]],
#
#        [[203, 587]]], dtype=int32), array([[[195, 587]],
#
#        [[196, 588]],
#
#        [[196, 589]],
#
#        [[196, 588]]], dtype=int32), array([[[160, 587]],
#
#        [[159, 588]],
#
#        [[160, 588]],
#
#        [[161, 589]],
#
#        [[163, 587]],
#
#        [[162, 588]],
#
#        [[161, 587]]], dtype=int32), array([[[733, 586]],
#
#        [[733, 589]]], dtype=int32), array([[[728, 586]],
#
#        [[728, 587]],
#
#        [[727, 588]],
#
#        [[727, 590]],
#
#        [[727, 588]],
#
#        [[728, 587]]], dtype=int32), array([[[679, 586]]], dtype=int32), array([[[388, 586]]], dtype=int32), array([[[785, 585]],
#
#        [[784, 586]],
#
#        [[784, 587]],
#
#        [[784, 586]]], dtype=int32), array([[[271, 585]],
#
#        [[271, 588]]], dtype=int32), array([[[258, 585]],
#
#        [[257, 586]],
#
#        [[258, 586]]], dtype=int32), array([[[143, 585]],
#
#        [[142, 586]],
#
#        [[142, 587]],
#
#        [[142, 586]]], dtype=int32), array([[[ 90, 585]],
#
#        [[ 89, 586]],
#
#        [[ 88, 586]],
#
#        [[ 86, 588]],
#
#        [[ 85, 588]],
#
#        [[ 85, 590]],
#
#        [[ 85, 589]],
#
#        [[ 88, 586]],
#
#        [[ 90, 586]]], dtype=int32), array([[[778, 584]],
#
#        [[779, 585]]], dtype=int32), array([[[756, 584]],
#
#        [[755, 585]],
#
#        [[754, 585]],
#
#        [[747, 592]],
#
#        [[754, 585]],
#
#        [[755, 585]]], dtype=int32), array([[[352, 584]]], dtype=int32), array([[[321, 584]],
#
#        [[321, 585]]], dtype=int32), array([[[188, 584]]], dtype=int32), array([[[186, 584]]], dtype=int32), array([[[785, 583]]], dtype=int32), array([[[675, 583]],
#
#        [[676, 583]]], dtype=int32), array([[[379, 583]],
#
#        [[379, 584]],
#
#        [[380, 585]],
#
#        [[380, 584]]], dtype=int32), array([[[137, 583]]], dtype=int32), array([[[931, 582]]], dtype=int32), array([[[758, 582]]], dtype=int32), array([[[347, 582]],
#
#        [[347, 583]],
#
#        [[348, 583]]], dtype=int32), array([[[272, 582]]], dtype=int32), array([[[269, 582]],
#
#        [[270, 583]]], dtype=int32), array([[[677, 581]]], dtype=int32), array([[[672, 581]]], dtype=int32), array([[[926, 580]],
#
#        [[927, 580]],
#
#        [[928, 581]],
#
#        [[929, 581]],
#
#        [[928, 580]]], dtype=int32), array([[[691, 580]],
#
#        [[691, 582]],
#
#        [[688, 585]],
#
#        [[687, 585]],
#
#        [[686, 584]],
#
#        [[687, 585]],
#
#        [[686, 586]],
#
#        [[686, 587]],
#
#        [[686, 586]],
#
#        [[687, 585]],
#
#        [[688, 585]],
#
#        [[690, 583]],
#
#        [[691, 583]]], dtype=int32), array([[[674, 580]]], dtype=int32), array([[[583, 580]]], dtype=int32), array([[[510, 580]]], dtype=int32), array([[[303, 580]],
#
#        [[303, 583]]], dtype=int32), array([[[165, 580]],
#
#        [[165, 583]]], dtype=int32), array([[[734, 579]],
#
#        [[734, 580]],
#
#        [[733, 581]],
#
#        [[733, 582]],
#
#        [[734, 581]]], dtype=int32), array([[[660, 579]],
#
#        [[659, 580]],
#
#        [[659, 581]],
#
#        [[658, 582]],
#
#        [[660, 580]]], dtype=int32), array([[[186, 579]],
#
#        [[186, 580]],
#
#        [[187, 581]],
#
#        [[187, 580]]], dtype=int32), array([[[696, 578]]], dtype=int32), array([[[692, 578]]], dtype=int32), array([[[681, 578]],
#
#        [[679, 580]]], dtype=int32), array([[[516, 578]],
#
#        [[516, 579]]], dtype=int32), array([[[366, 578]]], dtype=int32), array([[[243, 578]],
#
#        [[243, 579]],
#
#        [[242, 580]],
#
#        [[242, 581]],
#
#        [[240, 583]],
#
#        [[240, 584]],
#
#        [[240, 583]],
#
#        [[243, 580]]], dtype=int32), array([[[703, 577]],
#
#        [[702, 578]],
#
#        [[701, 578]],
#
#        [[697, 582]],
#
#        [[696, 582]],
#
#        [[696, 583]],
#
#        [[695, 584]],
#
#        [[695, 586]],
#
#        [[693, 588]],
#
#        [[694, 588]],
#
#        [[695, 587]],
#
#        [[695, 586]],
#
#        [[701, 580]],
#
#        [[701, 579]]], dtype=int32), array([[[678, 577]],
#
#        [[677, 578]]], dtype=int32), array([[[485, 577]]], dtype=int32), array([[[267, 577]],
#
#        [[267, 578]],
#
#        [[266, 579]],
#
#        [[265, 579]],
#
#        [[263, 581]],
#
#        [[263, 582]],
#
#        [[262, 583]],
#
#        [[265, 580]],
#
#        [[266, 580]],
#
#        [[266, 579]],
#
#        [[268, 577]]], dtype=int32), array([[[166, 577]]], dtype=int32), array([[[133, 577]],
#
#        [[133, 578]],
#
#        [[131, 580]],
#
#        [[130, 580]],
#
#        [[129, 579]],
#
#        [[130, 580]],
#
#        [[130, 581]],
#
#        [[129, 582]],
#
#        [[134, 577]]], dtype=int32), array([[[127, 577]]], dtype=int32), array([[[603, 576]]], dtype=int32), array([[[343, 576]],
#
#        [[343, 577]]], dtype=int32), array([[[206, 576]],
#
#        [[207, 577]],
#
#        [[208, 577]],
#
#        [[207, 577]]], dtype=int32), array([[[771, 575]],
#
#        [[770, 576]],
#
#        [[770, 577]],
#
#        [[768, 579]],
#
#        [[768, 580]],
#
#        [[766, 582]],
#
#        [[766, 583]],
#
#        [[765, 584]],
#
#        [[765, 585]],
#
#        [[766, 584]],
#
#        [[766, 583]],
#
#        [[767, 582]],
#
#        [[767, 581]],
#
#        [[768, 580]],
#
#        [[768, 579]],
#
#        [[770, 577]],
#
#        [[770, 576]]], dtype=int32), array([[[371, 575]]], dtype=int32), array([[[331, 575]]], dtype=int32), array([[[277, 575]]], dtype=int32), array([[[263, 575]],
#
#        [[264, 575]]], dtype=int32), array([[[694, 574]],
#
#        [[693, 575]]], dtype=int32), array([[[490, 574]],
#
#        [[490, 575]]], dtype=int32), array([[[273, 574]]], dtype=int32), array([[[267, 574]]], dtype=int32), array([[[167, 574]]], dtype=int32), array([[[155, 574]],
#
#        [[155, 575]],
#
#        [[154, 576]],
#
#        [[154, 577]],
#
#        [[154, 576]],
#
#        [[155, 575]]], dtype=int32), array([[[862, 573]]], dtype=int32), array([[[852, 573]],
#
#        [[851, 574]],
#
#        [[852, 573]],
#
#        [[853, 574]],
#
#        [[854, 574]],
#
#        [[853, 574]]], dtype=int32), array([[[822, 573]]], dtype=int32), array([[[773, 573]],
#
#        [[773, 574]]], dtype=int32), array([[[665, 573]]], dtype=int32), array([[[243, 573]]], dtype=int32), array([[[841, 572]],
#
#        [[842, 573]],
#
#        [[844, 573]],
#
#        [[843, 572]]], dtype=int32), array([[[659, 572]],
#
#        [[660, 572]]], dtype=int32), array([[[510, 572]],
#
#        [[510, 575]]], dtype=int32), array([[[487, 572]]], dtype=int32), array([[[666, 571]]], dtype=int32), array([[[654, 571]],
#
#        [[655, 572]],
#
#        [[654, 573]],
#
#        [[656, 573]],
#
#        [[657, 574]],
#
#        [[659, 574]],
#
#        [[660, 575]],
#
#        [[659, 574]],
#
#        [[658, 574]],
#
#        [[657, 573]],
#
#        [[657, 572]],
#
#        [[656, 572]],
#
#        [[655, 571]]], dtype=int32), array([[[619, 571]]], dtype=int32), array([[[513, 571]],
#
#        [[514, 572]],
#
#        [[514, 575]],
#
#        [[513, 576]],
#
#        [[514, 575]],
#
#        [[515, 576]],
#
#        [[514, 575]],
#
#        [[515, 574]],
#
#        [[516, 574]],
#
#        [[516, 573]],
#
#        [[515, 573]],
#
#        [[514, 572]],
#
#        [[514, 571]]], dtype=int32), array([[[482, 571]],
#
#        [[482, 573]],
#
#        [[483, 574]],
#
#        [[483, 576]],
#
#        [[482, 577]],
#
#        [[483, 576]],
#
#        [[483, 574]],
#
#        [[482, 573]]], dtype=int32), array([[[334, 571]]], dtype=int32), array([[[278, 571]],
#
#        [[277, 572]],
#
#        [[276, 572]],
#
#        [[277, 572]]], dtype=int32), array([[[249, 571]],
#
#        [[248, 572]],
#
#        [[248, 573]],
#
#        [[247, 574]],
#
#        [[246, 574]],
#
#        [[246, 575]],
#
#        [[245, 576]],
#
#        [[247, 574]],
#
#        [[248, 574]],
#
#        [[248, 573]],
#
#        [[249, 572]]], dtype=int32), array([[[150, 571]]], dtype=int32), array([[[728, 570]]], dtype=int32), array([[[705, 570]],
#
#        [[704, 571]]], dtype=int32), array([[[485, 570]],
#
#        [[485, 575]],
#
#        [[486, 575]],
#
#        [[486, 574]],
#
#        [[485, 573]]], dtype=int32), array([[[496, 569]]], dtype=int32), array([[[420, 569]],
#
#        [[421, 570]],
#
#        [[421, 571]],
#
#        [[421, 569]]], dtype=int32), array([[[263, 569]],
#
#        [[264, 570]]], dtype=int32), array([[[177, 569]],
#
#        [[178, 569]]], dtype=int32), array([[[766, 568]],
#
#        [[769, 571]]], dtype=int32), array([[[513, 568]]], dtype=int32), array([[[353, 568]]], dtype=int32), array([[[283, 568]],
#
#        [[282, 569]],
#
#        [[283, 568]],
#
#        [[284, 568]]], dtype=int32), array([[[895, 567]],
#
#        [[894, 568]],
#
#        [[892, 568]],
#
#        [[891, 569]],
#
#        [[890, 568]],
#
#        [[889, 568]],
#
#        [[888, 569]],
#
#        [[887, 569]],
#
#        [[888, 569]],
#
#        [[889, 570]],
#
#        [[890, 570]],
#
#        [[891, 569]],
#
#        [[892, 569]],
#
#        [[893, 568]],
#
#        [[894, 568]],
#
#        [[895, 567]],
#
#        [[896, 567]]], dtype=int32), array([[[888, 569]],
#
#        [[889, 568]],
#
#        [[890, 568]],
#
#        [[891, 569]],
#
#        [[890, 570]],
#
#        [[889, 570]]], dtype=int32), array([[[823, 567]],
#
#        [[823, 568]],
#
#        [[824, 568]],
#
#        [[825, 569]],
#
#        [[825, 567]]], dtype=int32), array([[[820, 567]],
#
#        [[820, 568]],
#
#        [[821, 569]],
#
#        [[821, 568]]], dtype=int32), array([[[815, 567]]], dtype=int32), array([[[494, 567]]], dtype=int32), array([[[155, 567]]], dtype=int32), array([[[808, 566]],
#
#        [[809, 566]]], dtype=int32), array([[[248, 566]],
#
#        [[247, 567]],
#
#        [[246, 567]],
#
#        [[250, 567]],
#
#        [[250, 566]]], dtype=int32), array([[[712, 565]],
#
#        [[712, 566]],
#
#        [[709, 569]],
#
#        [[709, 570]],
#
#        [[708, 571]],
#
#        [[707, 571]],
#
#        [[707, 572]],
#
#        [[706, 573]],
#
#        [[709, 570]],
#
#        [[709, 569]],
#
#        [[712, 566]]], dtype=int32), array([[[689, 565]],
#
#        [[688, 566]],
#
#        [[690, 566]],
#
#        [[691, 565]],
#
#        [[693, 565]],
#
#        [[691, 565]],
#
#        [[690, 566]]], dtype=int32), array([[[543, 565]]], dtype=int32), array([[[475, 564]]], dtype=int32), array([[[163, 564]],
#
#        [[161, 566]],
#
#        [[162, 565]],
#
#        [[163, 565]]], dtype=int32), array([[[799, 563]],
#
#        [[800, 563]]], dtype=int32), array([[[705, 563]]], dtype=int32), array([[[520, 563]],
#
#        [[520, 564]]], dtype=int32), array([[[507, 563]],
#
#        [[507, 564]]], dtype=int32), array([[[360, 563]],
#
#        [[361, 563]]], dtype=int32), array([[[806, 562]],
#
#        [[807, 562]],
#
#        [[808, 563]],
#
#        [[807, 562]]], dtype=int32), array([[[795, 562]]], dtype=int32), array([[[716, 562]],
#
#        [[717, 562]]], dtype=int32), array([[[546, 562]],
#
#        [[545, 563]],
#
#        [[545, 564]],
#
#        [[546, 564]]], dtype=int32), array([[[533, 562]],
#
#        [[533, 565]],
#
#        [[534, 566]],
#
#        [[534, 565]],
#
#        [[533, 564]]], dtype=int32), array([[[802, 561]],
#
#        [[803, 561]]], dtype=int32), array([[[519, 561]]], dtype=int32), array([[[536, 560]],
#
#        [[538, 562]],
#
#        [[538, 561]],
#
#        [[537, 561]]], dtype=int32), array([[[521, 560]],
#
#        [[522, 561]],
#
#        [[522, 567]],
#
#        [[524, 569]],
#
#        [[524, 570]],
#
#        [[525, 571]],
#
#        [[526, 571]],
#
#        [[526, 570]],
#
#        [[525, 569]],
#
#        [[525, 564]],
#
#        [[522, 561]],
#
#        [[522, 560]]], dtype=int32), array([[[516, 560]]], dtype=int32), array([[[504, 560]],
#
#        [[502, 562]],
#
#        [[502, 565]],
#
#        [[503, 564]],
#
#        [[503, 562]],
#
#        [[504, 561]]], dtype=int32), array([[[799, 559]]], dtype=int32), array([[[478, 559]]], dtype=int32), array([[[795, 558]],
#
#        [[795, 559]]], dtype=int32), array([[[532, 558]],
#
#        [[532, 559]],
#
#        [[533, 559]],
#
#        [[534, 560]],
#
#        [[534, 559]],
#
#        [[533, 559]]], dtype=int32), array([[[526, 557]],
#
#        [[526, 558]],
#
#        [[527, 559]],
#
#        [[527, 562]],
#
#        [[528, 562]],
#
#        [[529, 563]],
#
#        [[528, 564]],
#
#        [[527, 564]],
#
#        [[527, 566]],
#
#        [[528, 566]],
#
#        [[530, 568]],
#
#        [[530, 569]],
#
#        [[531, 569]],
#
#        [[528, 566]],
#
#        [[528, 564]],
#
#        [[529, 563]],
#
#        [[530, 564]],
#
#        [[531, 564]],
#
#        [[530, 563]],
#
#        [[530, 562]],
#
#        [[527, 559]],
#
#        [[527, 558]]], dtype=int32), array([[[695, 556]],
#
#        [[695, 559]]], dtype=int32), array([[[519, 556]],
#
#        [[519, 557]]], dtype=int32), array([[[506, 556]],
#
#        [[506, 557]],
#
#        [[507, 558]],
#
#        [[507, 559]],
#
#        [[506, 560]],
#
#        [[507, 559]],
#
#        [[507, 556]]], dtype=int32), array([[[500, 556]],
#
#        [[500, 558]],
#
#        [[501, 559]],
#
#        [[500, 560]],
#
#        [[500, 562]],
#
#        [[498, 564]],
#
#        [[497, 564]],
#
#        [[496, 563]],
#
#        [[497, 564]],
#
#        [[497, 565]],
#
#        [[496, 566]],
#
#        [[500, 566]],
#
#        [[499, 565]],
#
#        [[499, 564]],
#
#        [[500, 563]],
#
#        [[500, 560]],
#
#        [[501, 559]],
#
#        [[500, 558]]], dtype=int32), array([[[489, 556]]], dtype=int32), array([[[219, 556]]], dtype=int32), array([[[731, 555]]], dtype=int32), array([[[699, 555]],
#
#        [[699, 559]],
#
#        [[700, 560]],
#
#        [[701, 560]],
#
#        [[699, 558]],
#
#        [[699, 557]],
#
#        [[700, 556]]], dtype=int32), array([[[528, 555]]], dtype=int32), array([[[462, 555]],
#
#        [[461, 556]]], dtype=int32), array([[[349, 555]]], dtype=int32), array([[[707, 554]],
#
#        [[707, 555]]], dtype=int32), array([[[552, 554]],
#
#        [[552, 555]]], dtype=int32), array([[[524, 554]],
#
#        [[524, 556]]], dtype=int32), array([[[480, 554]],
#
#        [[479, 555]],
#
#        [[479, 557]],
#
#        [[479, 555]]], dtype=int32), array([[[541, 553]],
#
#        [[540, 554]],
#
#        [[540, 555]],
#
#        [[541, 554]],
#
#        [[543, 556]],
#
#        [[542, 557]],
#
#        [[542, 558]],
#
#        [[541, 559]],
#
#        [[540, 558]],
#
#        [[540, 559]],
#
#        [[541, 560]],
#
#        [[541, 563]],
#
#        [[543, 561]],
#
#        [[542, 561]],
#
#        [[541, 560]],
#
#        [[543, 558]],
#
#        [[544, 558]],
#
#        [[545, 559]],
#
#        [[547, 557]],
#
#        [[548, 558]],
#
#        [[548, 559]],
#
#        [[549, 559]],
#
#        [[549, 558]],
#
#        [[550, 557]],
#
#        [[549, 556]],
#
#        [[548, 556]],
#
#        [[547, 557]],
#
#        [[545, 557]],
#
#        [[544, 556]],
#
#        [[544, 554]],
#
#        [[543, 553]]], dtype=int32), array([[[551, 552]]], dtype=int32), array([[[520, 552]],
#
#        [[519, 553]],
#
#        [[519, 554]],
#
#        [[519, 553]]], dtype=int32), array([[[511, 552]],
#
#        [[511, 554]],
#
#        [[512, 553]]], dtype=int32), array([[[788, 551]],
#
#        [[789, 551]]], dtype=int32), array([[[747, 551]]], dtype=int32), array([[[490, 551]],
#
#        [[490, 553]]], dtype=int32), array([[[756, 550]],
#
#        [[754, 552]],
#
#        [[755, 551]],
#
#        [[757, 551]],
#
#        [[757, 550]]], dtype=int32), array([[[546, 550]],
#
#        [[545, 551]],
#
#        [[546, 552]],
#
#        [[546, 554]],
#
#        [[546, 551]],
#
#        [[547, 550]]], dtype=int32), array([[[556, 549]],
#
#        [[556, 550]]], dtype=int32), array([[[404, 549]]], dtype=int32), array([[[550, 548]],
#
#        [[550, 549]]], dtype=int32), array([[[471, 548]]], dtype=int32), array([[[447, 548]],
#
#        [[447, 549]]], dtype=int32), array([[[529, 547]],
#
#        [[529, 548]],
#
#        [[528, 549]],
#
#        [[529, 549]],
#
#        [[530, 548]],
#
#        [[530, 547]]], dtype=int32), array([[[167, 547]],
#
#        [[166, 548]],
#
#        [[165, 548]],
#
#        [[164, 549]],
#
#        [[163, 549]],
#
#        [[164, 550]],
#
#        [[165, 550]],
#
#        [[167, 548]],
#
#        [[168, 548]],
#
#        [[168, 547]]], dtype=int32), array([[[467, 546]]], dtype=int32), array([[[217, 545]],
#
#        [[217, 546]],
#
#        [[218, 546]],
#
#        [[221, 549]],
#
#        [[222, 549]],
#
#        [[223, 550]],
#
#        [[223, 549]],
#
#        [[222, 548]],
#
#        [[220, 548]],
#
#        [[219, 547]],
#
#        [[219, 546]],
#
#        [[218, 545]]], dtype=int32), array([[[565, 544]]], dtype=int32), array([[[931, 542]]], dtype=int32), array([[[214, 542]],
#
#        [[215, 543]],
#
#        [[216, 543]],
#
#        [[215, 543]]], dtype=int32), array([[[396, 541]]], dtype=int32), array([[[474, 540]],
#
#        [[473, 541]],
#
#        [[473, 544]],
#
#        [[472, 545]],
#
#        [[474, 545]],
#
#        [[474, 543]],
#
#        [[475, 542]],
#
#        [[476, 542]],
#
#        [[476, 541]],
#
#        [[475, 541]]], dtype=int32), array([[[274, 538]]], dtype=int32), array([[[512, 537]],
#
#        [[512, 538]]], dtype=int32), array([[[469, 537]],
#
#        [[468, 538]],
#
#        [[469, 538]]], dtype=int32), array([[[497, 535]]], dtype=int32), array([[[289, 535]],
#
#        [[289, 536]],
#
#        [[290, 537]],
#
#        [[290, 535]]], dtype=int32), array([[[515, 534]]], dtype=int32), array([[[499, 534]]], dtype=int32), array([[[474, 534]],
#
#        [[473, 535]],
#
#        [[472, 535]],
#
#        [[471, 536]],
#
#        [[472, 535]],
#
#        [[473, 536]],
#
#        [[473, 535]],
#
#        [[474, 534]],
#
#        [[475, 534]]], dtype=int32), array([[[188, 531]],
#
#        [[190, 533]],
#
#        [[190, 536]],
#
#        [[191, 537]],
#
#        [[191, 539]],
#
#        [[192, 540]],
#
#        [[192, 541]],
#
#        [[193, 542]],
#
#        [[193, 543]],
#
#        [[194, 544]],
#
#        [[195, 544]],
#
#        [[193, 542]],
#
#        [[193, 541]],
#
#        [[192, 540]],
#
#        [[192, 538]],
#
#        [[191, 537]],
#
#        [[191, 536]],
#
#        [[190, 535]],
#
#        [[190, 533]],
#
#        [[189, 532]],
#
#        [[189, 531]]], dtype=int32), array([[[501, 530]],
#
#        [[500, 531]]], dtype=int32), array([[[494, 530]],
#
#        [[494, 532]],
#
#        [[495, 533]],
#
#        [[494, 532]]], dtype=int32), array([[[492, 529]],
#
#        [[491, 530]],
#
#        [[491, 532]],
#
#        [[491, 531]],
#
#        [[492, 530]]], dtype=int32), array([[[552, 528]],
#
#        [[553, 529]]], dtype=int32), array([[[503, 528]]], dtype=int32), array([[[295, 528]],
#
#        [[296, 529]],
#
#        [[296, 530]],
#
#        [[297, 530]],
#
#        [[297, 529]],
#
#        [[296, 529]]], dtype=int32), array([[[133, 528]],
#
#        [[133, 530]]], dtype=int32), array([[[578, 527]],
#
#        [[579, 527]]], dtype=int32), array([[[550, 527]]], dtype=int32), array([[[522, 527]]], dtype=int32), array([[[489, 527]],
#
#        [[489, 529]],
#
#        [[490, 528]]], dtype=int32), array([[[485, 527]]], dtype=int32), array([[[563, 526]]], dtype=int32), array([[[502, 526]]], dtype=int32), array([[[492, 526]],
#
#        [[493, 526]]], dtype=int32), array([[[285, 526]],
#
#        [[285, 528]],
#
#        [[287, 530]],
#
#        [[287, 531]],
#
#        [[288, 532]],
#
#        [[288, 533]],
#
#        [[289, 532]],
#
#        [[288, 531]],
#
#        [[288, 529]],
#
#        [[287, 528]],
#
#        [[287, 527]],
#
#        [[286, 526]]], dtype=int32), array([[[424, 525]],
#
#        [[424, 526]],
#
#        [[425, 525]]], dtype=int32), array([[[529, 524]],
#
#        [[529, 525]],
#
#        [[530, 526]],
#
#        [[530, 529]],
#
#        [[529, 530]],
#
#        [[528, 529]],
#
#        [[528, 531]],
#
#        [[527, 532]],
#
#        [[527, 534]],
#
#        [[528, 535]],
#
#        [[527, 536]],
#
#        [[526, 536]],
#
#        [[527, 537]],
#
#        [[528, 536]],
#
#        [[529, 537]],
#
#        [[529, 538]],
#
#        [[530, 538]],
#
#        [[530, 534]],
#
#        [[531, 533]],
#
#        [[531, 526]],
#
#        [[530, 526]],
#
#        [[529, 525]]], dtype=int32), array([[[527, 534]],
#
#        [[528, 533]],
#
#        [[529, 534]],
#
#        [[528, 535]]], dtype=int32), array([[[528, 532]],
#
#        [[529, 531]],
#
#        [[530, 532]],
#
#        [[530, 533]],
#
#        [[529, 534]],
#
#        [[528, 533]]], dtype=int32), array([[[506, 524]]], dtype=int32), array([[[267, 524]],
#
#        [[271, 528]],
#
#        [[271, 530]],
#
#        [[272, 531]],
#
#        [[272, 532]],
#
#        [[273, 533]],
#
#        [[273, 536]],
#
#        [[274, 535]],
#
#        [[274, 532]],
#
#        [[273, 531]],
#
#        [[273, 530]],
#
#        [[272, 529]],
#
#        [[272, 526]],
#
#        [[270, 524]]], dtype=int32), array([[[221, 524]],
#
#        [[219, 526]],
#
#        [[219, 528]],
#
#        [[220, 528]],
#
#        [[220, 526]],
#
#        [[221, 525]]], dtype=int32), array([[[214, 524]],
#
#        [[214, 527]],
#
#        [[215, 528]],
#
#        [[215, 529]],
#
#        [[216, 529]],
#
#        [[216, 527]],
#
#        [[215, 526]],
#
#        [[215, 525]]], dtype=int32), array([[[208, 524]],
#
#        [[208, 525]],
#
#        [[209, 525]]], dtype=int32), array([[[932, 522]],
#
#        [[930, 524]],
#
#        [[930, 526]],
#
#        [[930, 525]],
#
#        [[932, 523]]], dtype=int32), array([[[922, 522]]], dtype=int32), array([[[512, 522]],
#
#        [[511, 523]],
#
#        [[511, 526]],
#
#        [[511, 524]],
#
#        [[512, 523]]], dtype=int32), array([[[538, 521]],
#
#        [[537, 522]],
#
#        [[537, 527]],
#
#        [[538, 528]],
#
#        [[539, 528]],
#
#        [[540, 529]],
#
#        [[540, 530]],
#
#        [[542, 532]],
#
#        [[542, 533]],
#
#        [[543, 533]],
#
#        [[544, 534]],
#
#        [[544, 536]],
#
#        [[544, 535]],
#
#        [[545, 534]],
#
#        [[545, 523]],
#
#        [[544, 522]],
#
#        [[544, 521]],
#
#        [[543, 521]],
#
#        [[543, 523]],
#
#        [[542, 524]],
#
#        [[541, 524]],
#
#        [[541, 527]],
#
#        [[540, 528]],
#
#        [[539, 527]],
#
#        [[539, 526]],
#
# ...
#
#        [[596, 434]]], dtype=int32), array([[[485, 431]],
#
#        [[486, 430]],
#
#        [[487, 430]],
#
#        [[488, 431]],
#
#        [[485, 434]],
#
#        [[484, 434]],
#
#        [[483, 433]],
#
#        [[483, 432]],
#
#        [[484, 431]]], dtype=int32), array([[[595, 430]],
#
#        [[596, 429]],
#
#        [[599, 429]],
#
#        [[600, 430]],
#
#        [[599, 431]],
#
#        [[596, 431]]], dtype=int32), array([[[487, 429]],
#
#        [[488, 428]],
#
#        [[489, 429]],
#
#        [[489, 430]],
#
#        [[488, 431]],
#
#        [[487, 430]]], dtype=int32), array([[[468, 428]],
#
#        [[469, 427]],
#
#        [[470, 427]],
#
#        [[471, 428]],
#
#        [[470, 429]],
#
#        [[469, 429]]], dtype=int32), array([[[462, 428]],
#
#        [[463, 427]],
#
#        [[464, 428]],
#
#        [[463, 429]]], dtype=int32), array([[[470, 426]],
#
#        [[471, 425]],
#
#        [[472, 426]],
#
#        [[471, 427]]], dtype=int32), array([[[471, 425]],
#
#        [[472, 424]],
#
#        [[473, 424]],
#
#        [[474, 425]],
#
#        [[473, 426]],
#
#        [[472, 426]]], dtype=int32), array([[[588, 424]],
#
#        [[589, 423]],
#
#        [[591, 423]],
#
#        [[592, 424]],
#
#        [[591, 425]],
#
#        [[589, 425]]], dtype=int32), array([[[594, 423]],
#
#        [[595, 422]],
#
#        [[597, 422]],
#
#        [[598, 423]],
#
#        [[597, 424]],
#
#        [[595, 424]]], dtype=int32), array([[[520, 422]],
#
#        [[521, 421]],
#
#        [[522, 422]],
#
#        [[521, 423]]], dtype=int32), array([[[492, 422]],
#
#        [[493, 421]],
#
#        [[495, 421]],
#
#        [[497, 423]],
#
#        [[497, 424]],
#
#        [[498, 424]],
#
#        [[499, 425]],
#
#        [[501, 425]],
#
#        [[502, 426]],
#
#        [[499, 429]],
#
#        [[501, 431]],
#
#        [[500, 432]],
#
#        [[499, 432]],
#
#        [[499, 434]],
#
#        [[498, 435]],
#
#        [[497, 435]],
#
#        [[496, 434]],
#
#        [[495, 434]],
#
#        [[494, 433]],
#
#        [[496, 431]],
#
#        [[492, 431]],
#
#        [[491, 430]],
#
#        [[491, 429]],
#
#        [[490, 429]],
#
#        [[489, 428]],
#
#        [[491, 426]],
#
#        [[489, 426]],
#
#        [[488, 425]],
#
#        [[491, 422]]], dtype=int32), array([[[593, 421]],
#
#        [[594, 420]],
#
#        [[595, 421]],
#
#        [[594, 422]]], dtype=int32), array([[[488, 419]],
#
#        [[489, 418]],
#
#        [[490, 418]],
#
#        [[492, 420]],
#
#        [[490, 422]],
#
#        [[489, 421]],
#
#        [[489, 420]]], dtype=int32), array([[[484, 418]],
#
#        [[485, 417]],
#
#        [[486, 418]],
#
#        [[485, 419]]], dtype=int32), array([[[521, 415]],
#
#        [[522, 415]],
#
#        [[523, 416]],
#
#        [[523, 417]],
#
#        [[522, 418]],
#
#        [[523, 419]],
#
#        [[523, 420]],
#
#        [[522, 421]],
#
#        [[521, 421]],
#
#        [[519, 419]],
#
#        [[519, 417]]], dtype=int32), array([[[547, 414]],
#
#        [[548, 414]],
#
#        [[549, 415]],
#
#        [[549, 416]],
#
#        [[548, 417]],
#
#        [[548, 421]],
#
#        [[547, 422]],
#
#        [[546, 421]],
#
#        [[546, 418]],
#
#        [[545, 417]],
#
#        [[545, 416]]], dtype=int32), array([[[417, 413]],
#
#        [[418, 412]],
#
#        [[419, 413]],
#
#        [[418, 414]]], dtype=int32), array([[[462, 406]],
#
#        [[463, 405]],
#
#        [[464, 406]],
#
#        [[463, 407]]], dtype=int32), array([[[513, 401]],
#
#        [[515, 401]],
#
#        [[516, 402]],
#
#        [[517, 402]],
#
#        [[518, 403]],
#
#        [[518, 406]],
#
#        [[517, 407]],
#
#        [[516, 406]],
#
#        [[516, 405]],
#
#        [[515, 404]],
#
#        [[514, 405]],
#
#        [[513, 405]],
#
#        [[511, 403]]], dtype=int32), array([[[497, 399]],
#
#        [[498, 400]],
#
#        [[498, 401]],
#
#        [[508, 401]],
#
#        [[511, 404]],
#
#        [[511, 405]],
#
#        [[513, 407]],
#
#        [[513, 408]],
#
#        [[516, 408]],
#
#        [[517, 409]],
#
#        [[519, 409]],
#
#        [[520, 410]],
#
#        [[519, 411]],
#
#        [[519, 412]],
#
#        [[520, 413]],
#
#        [[520, 414]],
#
#        [[519, 415]],
#
#        [[518, 415]],
#
#        [[516, 413]],
#
#        [[516, 412]],
#
#        [[515, 412]],
#
#        [[514, 413]],
#
#        [[514, 415]],
#
#        [[512, 417]],
#
#        [[509, 414]],
#
#        [[508, 414]],
#
#        [[507, 413]],
#
#        [[506, 413]],
#
#        [[505, 412]],
#
#        [[502, 412]],
#
#        [[501, 411]],
#
#        [[499, 411]],
#
#        [[498, 410]],
#
#        [[497, 410]],
#
#        [[495, 408]],
#
#        [[494, 408]],
#
#        [[493, 407]],
#
#        [[492, 407]],
#
#        [[490, 409]],
#
#        [[490, 410]],
#
#        [[491, 410]],
#
#        [[492, 411]],
#
#        [[492, 412]],
#
#        [[491, 413]],
#
#        [[490, 413]],
#
#        [[490, 414]],
#
#        [[491, 414]],
#
#        [[492, 415]],
#
#        [[491, 416]],
#
#        [[491, 417]],
#
#        [[490, 418]],
#
#        [[489, 417]],
#
#        [[486, 417]],
#
#        [[485, 416]],
#
#        [[479, 416]],
#
#        [[478, 417]],
#
#        [[475, 417]],
#
#        [[474, 416]],
#
#        [[473, 416]],
#
#        [[474, 416]],
#
#        [[476, 418]],
#
#        [[475, 419]],
#
#        [[473, 419]],
#
#        [[470, 416]],
#
#        [[469, 416]],
#
#        [[470, 417]],
#
#        [[469, 418]],
#
#        [[467, 418]],
#
#        [[468, 418]],
#
#        [[469, 419]],
#
#        [[473, 419]],
#
#        [[474, 420]],
#
#        [[475, 420]],
#
#        [[476, 421]],
#
#        [[475, 422]],
#
#        [[469, 422]],
#
#        [[471, 422]],
#
#        [[472, 423]],
#
#        [[472, 424]],
#
#        [[471, 425]],
#
#        [[467, 425]],
#
#        [[466, 424]],
#
#        [[465, 424]],
#
#        [[465, 425]],
#
#        [[464, 426]],
#
#        [[462, 426]],
#
#        [[461, 427]],
#
#        [[459, 427]],
#
#        [[457, 429]],
#
#        [[456, 429]],
#
#        [[455, 430]],
#
#        [[455, 431]],
#
#        [[454, 432]],
#
#        [[454, 434]],
#
#        [[453, 435]],
#
#        [[451, 435]],
#
#        [[448, 438]],
#
#        [[447, 438]],
#
#        [[446, 437]],
#
#        [[446, 436]],
#
#        [[450, 432]],
#
#        [[452, 432]],
#
#        [[452, 430]],
#
#        [[451, 431]],
#
#        [[448, 431]],
#
#        [[447, 430]],
#
#        [[448, 429]],
#
#        [[448, 428]],
#
#        [[447, 428]],
#
#        [[446, 427]],
#
#        [[451, 422]],
#
#        [[451, 421]],
#
#        [[455, 417]],
#
#        [[457, 417]],
#
#        [[457, 416]],
#
#        [[459, 414]],
#
#        [[460, 414]],
#
#        [[461, 413]],
#
#        [[462, 413]],
#
#        [[463, 414]],
#
#        [[465, 412]],
#
#        [[464, 413]],
#
#        [[463, 413]],
#
#        [[462, 412]],
#
#        [[464, 410]],
#
#        [[463, 410]],
#
#        [[462, 409]],
#
#        [[462, 408]],
#
#        [[464, 406]],
#
#        [[464, 404]],
#
#        [[465, 403]],
#
#        [[466, 403]],
#
#        [[467, 402]],
#
#        [[468, 402]],
#
#        [[469, 401]],
#
#        [[471, 401]],
#
#        [[472, 400]],
#
#        [[473, 401]],
#
#        [[474, 401]],
#
#        [[475, 400]],
#
#        [[476, 401]],
#
#        [[478, 401]],
#
#        [[479, 402]],
#
#        [[479, 403]],
#
#        [[480, 404]],
#
#        [[480, 406]],
#
#        [[482, 406]],
#
#        [[483, 405]],
#
#        [[484, 405]],
#
#        [[485, 404]],
#
#        [[486, 404]],
#
#        [[487, 403]],
#
#        [[488, 403]],
#
#        [[489, 404]],
#
#        [[488, 405]],
#
#        [[488, 406]],
#
#        [[489, 406]],
#
#        [[490, 405]],
#
#        [[491, 405]],
#
#        [[492, 404]],
#
#        [[492, 403]],
#
#        [[494, 401]],
#
#        [[495, 401]]], dtype=int32), array([[[459, 425]],
#
#        [[460, 425]]], dtype=int32), array([[[452, 424]],
#
#        [[451, 425]],
#
#        [[453, 425]],
#
#        [[454, 424]]], dtype=int32), array([[[464, 422]],
#
#        [[466, 422]]], dtype=int32), array([[[455, 420]],
#
#        [[455, 421]]], dtype=int32), array([[[463, 418]],
#
#        [[464, 418]]], dtype=int32), array([[[500, 406]],
#
#        [[500, 407]],
#
#        [[501, 408]],
#
#        [[502, 408]],
#
#        [[503, 409]],
#
#        [[504, 408]],
#
#        [[505, 408]],
#
#        [[506, 407]],
#
#        [[506, 406]],
#
#        [[504, 408]],
#
#        [[502, 408]]], dtype=int32), array([[[549, 398]],
#
#        [[558, 398]],
#
#        [[559, 399]],
#
#        [[565, 399]],
#
#        [[566, 400]],
#
#        [[567, 400]],
#
#        [[568, 399]],
#
#        [[570, 401]],
#
#        [[570, 402]],
#
#        [[572, 404]],
#
#        [[572, 405]],
#
#        [[571, 406]],
#
#        [[569, 406]],
#
#        [[565, 410]],
#
#        [[564, 410]],
#
#        [[563, 411]],
#
#        [[562, 411]],
#
#        [[560, 413]],
#
#        [[557, 413]],
#
#        [[554, 416]],
#
#        [[551, 413]],
#
#        [[550, 414]],
#
#        [[548, 414]],
#
#        [[547, 413]],
#
#        [[547, 412]],
#
#        [[545, 410]],
#
#        [[545, 408]],
#
#        [[546, 407]],
#
#        [[545, 406]],
#
#        [[545, 405]],
#
#        [[546, 404]],
#
#        [[546, 403]],
#
#        [[547, 402]],
#
#        [[547, 400]]], dtype=int32), array([[[550, 405]],
#
#        [[551, 406]],
#
#        [[551, 407]],
#
#        [[552, 406]],
#
#        [[552, 405]]], dtype=int32), array([[[564, 404]],
#
#        [[561, 407]],
#
#        [[560, 407]],
#
#        [[559, 406]],
#
#        [[559, 407]],
#
#        [[563, 407]],
#
#        [[564, 406]]], dtype=int32), array([[[562, 398]],
#
#        [[563, 397]],
#
#        [[564, 397]],
#
#        [[565, 398]],
#
#        [[564, 399]],
#
#        [[563, 399]]], dtype=int32), array([[[586, 396]],
#
#        [[588, 396]],
#
#        [[591, 399]],
#
#        [[590, 400]],
#
#        [[589, 400]],
#
#        [[590, 400]],
#
#        [[591, 401]],
#
#        [[591, 402]],
#
#        [[592, 402]],
#
#        [[593, 403]],
#
#        [[593, 404]],
#
#        [[592, 405]],
#
#        [[592, 409]],
#
#        [[597, 414]],
#
#        [[595, 416]],
#
#        [[592, 416]],
#
#        [[591, 415]],
#
#        [[590, 416]],
#
#        [[588, 416]],
#
#        [[590, 416]],
#
#        [[591, 417]],
#
#        [[592, 416]],
#
#        [[595, 416]],
#
#        [[597, 418]],
#
#        [[596, 419]],
#
#        [[594, 419]],
#
#        [[594, 420]],
#
#        [[593, 421]],
#
#        [[590, 421]],
#
#        [[588, 419]],
#
#        [[586, 419]],
#
#        [[584, 417]],
#
#        [[584, 416]],
#
#        [[582, 416]],
#
#        [[580, 414]],
#
#        [[580, 412]],
#
#        [[577, 412]],
#
#        [[571, 406]],
#
#        [[573, 404]],
#
#        [[574, 405]],
#
#        [[581, 405]],
#
#        [[582, 404]],
#
#        [[581, 403]],
#
#        [[581, 402]],
#
#        [[582, 401]],
#
#        [[583, 401]],
#
#        [[584, 402]],
#
#        [[584, 401]],
#
#        [[583, 400]],
#
#        [[583, 399]]], dtype=int32), array([[[589, 407]],
#
#        [[590, 407]]], dtype=int32), array([[[584, 396]],
#
#        [[585, 395]],
#
#        [[586, 396]],
#
#        [[585, 397]]], dtype=int32), array([[[475, 396]],
#
#        [[476, 395]],
#
#        [[477, 395]],
#
#        [[479, 397]],
#
#        [[477, 399]],
#
#        [[476, 399]],
#
#        [[474, 401]],
#
#        [[473, 401]],
#
#        [[472, 400]],
#
#        [[471, 400]],
#
#        [[470, 401]],
#
#        [[466, 401]],
#
#        [[465, 400]],
#
#        [[466, 399]],
#
#        [[467, 399]],
#
#        [[469, 397]],
#
#        [[470, 397]],
#
#        [[471, 396]]], dtype=int32), array([[[513, 393]],
#
#        [[514, 392]],
#
#        [[517, 395]],
#
#        [[515, 397]],
#
#        [[514, 396]],
#
#        [[514, 395]],
#
#        [[513, 394]]], dtype=int32), array([[[473, 393]],
#
#        [[474, 392]],
#
#        [[475, 392]],
#
#        [[476, 393]],
#
#        [[475, 394]],
#
#        [[474, 394]]], dtype=int32), array([[[475, 392]],
#
#        [[476, 391]],
#
#        [[477, 391]],
#
#        [[478, 392]],
#
#        [[477, 393]],
#
#        [[476, 393]]], dtype=int32), array([[[532, 371]],
#
#        [[533, 370]],
#
#        [[534, 371]],
#
#        [[533, 372]]], dtype=int32), array([[[531, 370]],
#
#        [[532, 369]],
#
#        [[533, 370]],
#
#        [[532, 371]]], dtype=int32), array([[[594, 363]],
#
#        [[595, 362]],
#
#        [[596, 362]],
#
#        [[598, 364]],
#
#        [[598, 366]],
#
#        [[597, 367]],
#
#        [[597, 368]],
#
#        [[596, 369]],
#
#        [[596, 371]],
#
#        [[597, 372]],
#
#        [[597, 373]],
#
#        [[596, 374]],
#
#        [[595, 374]],
#
#        [[594, 373]],
#
#        [[593, 373]],
#
#        [[591, 371]],
#
#        [[591, 370]],
#
#        [[589, 368]],
#
#        [[589, 366]],
#
#        [[588, 366]],
#
#        [[587, 365]],
#
#        [[589, 363]]], dtype=int32), array([[[601, 334]],
#
#        [[602, 335]],
#
#        [[602, 340]],
#
#        [[600, 342]],
#
#        [[600, 343]],
#
#        [[599, 344]],
#
#        [[599, 345]],
#
#        [[598, 346]],
#
#        [[598, 347]],
#
#        [[597, 348]],
#
#        [[596, 348]],
#
#        [[594, 350]],
#
#        [[594, 351]],
#
#        [[597, 354]],
#
#        [[597, 355]],
#
#        [[596, 356]],
#
#        [[597, 357]],
#
#        [[597, 358]],
#
#        [[598, 359]],
#
#        [[598, 360]],
#
#        [[596, 362]],
#
#        [[594, 362]],
#
#        [[593, 363]],
#
#        [[589, 363]],
#
#        [[588, 362]],
#
#        [[588, 360]],
#
#        [[589, 359]],
#
#        [[589, 358]],
#
#        [[588, 357]],
#
#        [[588, 356]],
#
#        [[587, 355]],
#
#        [[587, 352]],
#
#        [[590, 349]],
#
#        [[590, 348]],
#
#        [[592, 346]],
#
#        [[592, 344]],
#
#        [[593, 343]],
#
#        [[593, 342]],
#
#        [[595, 340]],
#
#        [[596, 340]],
#
#        [[597, 339]],
#
#        [[597, 338]]], dtype=int32), array([[[475, 335]],
#
#        [[476, 334]],
#
#        [[477, 335]],
#
#        [[476, 336]]], dtype=int32), array([[[602, 332]],
#
#        [[603, 331]],
#
#        [[604, 332]],
#
#        [[604, 333]],
#
#        [[603, 334]],
#
#        [[602, 333]]], dtype=int32), array([[[607, 325]],
#
#        [[608, 326]],
#
#        [[608, 327]],
#
#        [[607, 328]],
#
#        [[607, 329]],
#
#        [[606, 330]],
#
#        [[605, 330]],
#
#        [[604, 329]],
#
#        [[605, 328]],
#
#        [[605, 327]]], dtype=int32), array([[[436, 323]],
#
#        [[437, 322]],
#
#        [[438, 322]],
#
#        [[440, 324]],
#
#        [[441, 324]],
#
#        [[442, 325]],
#
#        [[442, 326]],
#
#        [[443, 326]],
#
#        [[448, 331]],
#
#        [[448, 332]],
#
#        [[451, 335]],
#
#        [[452, 334]],
#
#        [[453, 334]],
#
#        [[454, 335]],
#
#        [[454, 336]],
#
#        [[460, 342]],
#
#        [[460, 343]],
#
#        [[461, 343]],
#
#        [[468, 350]],
#
#        [[468, 351]],
#
#        [[469, 351]],
#
#        [[472, 354]],
#
#        [[472, 357]],
#
#        [[471, 358]],
#
#        [[472, 359]],
#
#        [[471, 360]],
#
#        [[470, 360]],
#
#        [[470, 362]],
#
#        [[469, 363]],
#
#        [[468, 363]],
#
#        [[468, 365]],
#
#        [[467, 366]],
#
#        [[470, 369]],
#
#        [[466, 373]],
#
#        [[466, 374]],
#
#        [[464, 376]],
#
#        [[463, 376]],
#
#        [[464, 377]],
#
#        [[463, 378]],
#
#        [[462, 378]],
#
#        [[458, 382]],
#
#        [[454, 382]],
#
#        [[453, 383]],
#
#        [[450, 383]],
#
#        [[449, 382]],
#
#        [[449, 378]],
#
#        [[448, 377]],
#
#        [[448, 375]],
#
#        [[447, 374]],
#
#        [[447, 373]],
#
#        [[446, 372]],
#
#        [[446, 371]],
#
#        [[447, 370]],
#
#        [[447, 368]],
#
#        [[446, 368]],
#
#        [[445, 367]],
#
#        [[445, 366]],
#
#        [[444, 365]],
#
#        [[444, 362]],
#
#        [[445, 361]],
#
#        [[444, 360]],
#
#        [[444, 355]],
#
#        [[442, 353]],
#
#        [[442, 351]],
#
#        [[441, 350]],
#
#        [[441, 349]],
#
#        [[440, 348]],
#
#        [[440, 346]],
#
#        [[439, 345]],
#
#        [[439, 342]],
#
#        [[438, 341]],
#
#        [[438, 337]],
#
#        [[437, 336]],
#
#        [[437, 332]],
#
#        [[436, 331]]], dtype=int32), array([[[455, 355]]], dtype=int32), array([[[743, 281]],
#
#        [[743, 286]]], dtype=int32), array([[[780, 246]],
#
#        [[780, 247]]], dtype=int32), array([[[781, 243]],
#
#        [[782, 243]]], dtype=int32), array([[[783, 234]],
#
#        [[782, 235]],
#
#        [[783, 235]]], dtype=int32), array([[[782, 229]],
#
#        [[783, 229]]], dtype=int32), array([[[784, 208]],
#
#        [[781, 211]],
#
#        [[781, 219]],
#
#        [[782, 220]],
#
#        [[782, 214]],
#
#        [[784, 212]],
#
#        [[784, 211]],
#
#        [[785, 210]],
#
#        [[785, 209]]], dtype=int32), array([[[785, 192]],
#
#        [[785, 196]],
#
#        [[784, 197]],
#
#        [[784, 201]],
#
#        [[783, 202]],
#
#        [[783, 204]],
#
#        [[784, 205]],
#
#        [[784, 206]],
#
#        [[784, 204]],
#
#        [[785, 203]],
#
#        [[785, 195]],
#
#        [[786, 194]],
#
#        [[786, 192]]], dtype=int32), array([[[790, 190]],
#
#        [[790, 191]]], dtype=int32), array([[[785, 186]],
#
#        [[785, 187]],
#
#        [[786, 188]],
#
#        [[786, 187]]], dtype=int32), array([[[788, 174]],
#
#        [[788, 175]]], dtype=int32), array([[[786, 168]],
#
#        [[786, 169]],
#
#        [[789, 169]],
#
#        [[788, 169]],
#
#        [[787, 168]]], dtype=int32))

# %%
image_puma =  cv2.imread("input\puma.jpg", cv2.IMREAD_GRAYSCALE)

plt.imshow(image_puma, cmap="gray")

# %%
image_puma = 255 - image_puma

plt.imshow(image_puma, cmap="gray")
plt.show()

# %%
_, image_puma_thresh = cv2.threshold(image_puma, 115, 255, cv2.THRESH_BINARY)

# %%
contours, _ = cv2.findContours(image_puma_thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

result = image_puma.copy()

for contour in contours:
    if cv2.contourArea(contour) > 100:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(result, (x,y), (x+w, y+h), (127, 127, 127), 3)

plt.imshow(result, cmap="gray")

# %%
image_coins = cv2.imread("input\coins.jpg", cv2.IMREAD_GRAYSCALE)
plt.axis('off')
plt.imshow(image_coins, cmap="gray")
plt.show()

# %%
_, image_coins_thresh = cv2.threshold(image_coins, 90, 255, cv2.THRESH_BINARY)
plt.axis('off')
plt.imshow(image_coins_thresh, cmap="gray")
plt.show()

# %%
contours, hierarch = cv2.findContours(image_coins_thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
result = image_coins.copy()

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(result, (x, y), (x+w, y+h), (127, 127, 127), 3)

    plt.axis('off')
    plt.imshow(result, cmap='gray')
    plt.show()
